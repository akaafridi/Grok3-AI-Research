# %%
# MoE_Routing_Simulation.ipynb

import random
import matplotlib.pyplot as plt

print("🔀 Simulating MoE Routing for Grok-3")

experts = ["Expert A", "Expert B", "Expert C", "Expert D"]
token_inputs = [f"Token_{i}" for i in range(20)]

# Simulate routing decisions
routing_log = {expert: 0 for expert in experts}

for token in token_inputs:
    selected_expert = random.choices(experts, weights=[0.4, 0.3, 0.2, 0.1])[0]
    routing_log[selected_expert] += 1
    print(f"{token} routed to {selected_expert}")

# Plot
plt.figure(figsize=(6,4))
plt.bar(routing_log.keys(), routing_log.values(), color='purple')
plt.title("Token Distribution Across Experts (Grok-3 MoE Simulation)")
plt.ylabel("Number of Tokens")
plt.xlabel("Expert")
plt.grid(True)
plt.show()
# Out:
# 🔀 Simulating MoE Routing for Grok-3
# Token_0 routed to Expert A
# Token_1 routed to Expert A
# Token_2 routed to Expert B
# Token_3 routed to Expert A
# Token_4 routed to Expert A
# Token_5 routed to Expert C
# Token_6 routed to Expert C
# Token_7 routed to Expert A
# Token_8 routed to Expert A
# Token_9 routed to Expert B
# Token_10 routed to Expert C
# Token_11 routed to Expert B
# Token_12 routed to Expert A
# Token_13 routed to Expert C
# Token_14 routed to Expert A
# Token_15 routed to Expert D
# Token_16 routed to Expert A
# Token_17 routed to Expert A
# Token_18 routed to Expert D
# Token_19 routed to Expert B
